# %%
import pandas as pd

# %%
data = pd.read_excel('C:/Users/it/dataset/big_mart_sales.xlsx')

# %%
data.head(2)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDA15         9.30          Low Fat         0.016047        Dairy
# 1           DRC01         5.92          Regular         0.019278  Soft Drinks
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  249.8092            OUT049                       1999      Medium
# 1   48.2692            OUT018                       2009      Medium
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0               Tier 1  Supermarket Type1          3735.1380
# 1               Tier 3  Supermarket Type2           443.4228

# %% [markdown]
# ----
# #### ***`[1] EXCEL FILES WITH MULTIPLE SHEETS: SPECIFY THE SHEET NAME`***
# ----

# %%
data_with_multiple_sheets = pd.read_excel('C:/Users/it/dataset/big_mart_sales_with_multiple_sheets.xlsx')

# %%
# unique year present in the data
data_with_multiple_sheets.Outlet_Establishment_Year.unique()
# Out:
# array([1985], dtype=int64)

# %%
sheet_1985 = pd.read_excel('C:/Users/it/dataset/big_mart_sales_with_multiple_sheets.xlsx',sheet_name='1985')
sheet_1985.head(2)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDP10          NaN          Low Fat         0.127470  Snack Foods
# 1           DRI11          NaN          Low Fat         0.034238  Hard Drinks
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  107.7622            OUT027                       1985      Medium
# 1  113.2834            OUT027                       1985      Medium
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0               Tier 3  Supermarket Type3          4022.7636
# 1               Tier 3  Supermarket Type3          2303.6680

# %%
sheet_1987 = pd.read_excel('C:/Users/it/dataset/big_mart_sales_with_multiple_sheets.xlsx',sheet_name='1987')
sheet_1987.head(2)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           NCD19         8.93          Low Fat         0.000000    Household
# 1           FDO10        13.65          Regular         0.012741  Snack Foods
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0   53.8614            OUT013                       1987        High
# 1   57.6588            OUT013                       1987        High
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0               Tier 3  Supermarket Type1           994.7052
# 1               Tier 3  Supermarket Type1           343.5528

# %%
sheet_1997 = pd.read_excel('C:/Users/it/dataset/big_mart_sales_with_multiple_sheets.xlsx',sheet_name='1997')
sheet_1997.head(2)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDA03         18.5          Regular         0.045464        Dairy
# 1           FDS46         17.6          Regular         0.047257  Snack Foods
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  144.1102            OUT046                       1997       Small
# 1  119.6782            OUT046                       1997       Small
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0               Tier 1  Supermarket Type1          2187.1530
# 1               Tier 1  Supermarket Type1          2145.2076

# %%
sheets = [sheet_1985, sheet_1987, sheet_1997]
final_data = pd.concat(sheets)

# %%
final_data.Outlet_Establishment_Year.unique()
# Out:
# array([1985, 1987, 1997], dtype=int64)

# %% [markdown]
# ---
#
# ***[2] If we have comments on the top of a file. We can use `skiprows` to skip the first n rows and read the data.***
#
# ---

# %%
sheet_with_comments = pd.read_excel('C:/Users/it/dataset/big_mart_sales_comments.xlsx')
sheet_with_comments.head()
# Out:
#    # This is Big Mart Sales Data   Unnamed: 1        Unnamed: 2  \
# 0  # This is Big Mart Sales Data          NaN               NaN
# 1  # This is Big Mart Sales Data          NaN               NaN
# 2                Item_Identifier  Item_Weight  Item_Fat_Content
# 3                          FDA15          9.3           Low Fat
# 4                          DRC01         5.92           Regular
#
#         Unnamed: 3   Unnamed: 4 Unnamed: 5         Unnamed: 6  \
# 0              NaN          NaN        NaN                NaN
# 1              NaN          NaN        NaN                NaN
# 2  Item_Visibility    Item_Type   Item_MRP  Outlet_Identifier
# 3         0.016047        Dairy   249.8092             OUT049
# 4         0.019278  Soft Drinks    48.2692             OUT018
#
#                   Unnamed: 7   Unnamed: 8            Unnamed: 9  \
# 0                        NaN          NaN                   NaN
# 1                        NaN          NaN                   NaN
# ...

# %%
sheet_with_comments = pd.read_excel('C:/Users/it/dataset/big_mart_sales_comments.xlsx',skiprows=3)
sheet_with_comments.head(2)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDA15         9.30          Low Fat         0.016047        Dairy
# 1           DRC01         5.92          Regular         0.019278  Soft Drinks
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  249.8092            OUT049                       1999      Medium
# 1   48.2692            OUT018                       2009      Medium
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0               Tier 1  Supermarket Type1          3735.1380
# 1               Tier 3  Supermarket Type2           443.4228

# %% [markdown]
# ----
# ### `[3] ASSIGNMENT: READ FILES FROM MULTIPLE DIRECTORIES`
# ----
